# %%
#Load the  "iris_data_with_missing_values.csv"
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %% [markdown]
# <b>Q-1: Create a dataframe and label the columns.

# %%
#solution to q-1
df = pd.read_csv('iris_data_with_missing_values.csv',header=None, names=['sepal length', 'sepal width','petal length','petal width','Class'])
df
# Out:
#      sepal length  sepal width  petal length  petal width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          NaN           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <b> Q-2:  Sample the dataset with and without replacement (20%data)

# %%
#solution to q-2
df1 = df.sample(frac =.2)
df2 = df.sample(frac =.2, replace = True)

# %% [markdown]
# <b>Q-3:Normalize the dataset using z-score normalization

# %%
#solution to q-3
zsdf = df.copy()
for feature_name in zsdf.columns[:4]:
    mean = zsdf[feature_name].mean()
    std = zsdf[feature_name].std()
    zsdf[feature_name] = (zsdf[feature_name] - mean) / std
print(zsdf.to_string())
# Out:
#      sepal length  sepal width  petal length  petal width            Class
# 0       -0.724647     0.294610     -1.337992    -1.298154      Iris-setosa
# 1       -0.903828    -0.113183     -1.337992    -1.298154      Iris-setosa
# 2       -1.083009     0.049934     -1.392902    -1.298154      Iris-setosa
# 3       -1.172599    -0.031625     -1.283083    -1.298154      Iris-setosa
# 4       -0.814237     0.376169     -1.337992    -1.298154      Iris-setosa
# 5       -0.455875     0.620844     -1.173265    -1.037820      Iris-setosa
# 6       -1.172599     0.213051     -1.337992    -1.167987      Iris-setosa
# 7       -0.814237     0.213051      3.384202    -1.298154      Iris-setosa
# 8       -1.351780    -0.194742     -1.337992    -1.298154      Iris-setosa
# 9       -0.903828    -0.031625     -1.283083    -1.428321      Iris-setosa
# 10      -0.455875     0.457727     -1.283083    -1.298154      Iris-setosa
# ...

# %% [markdown]
# <b>Q-4:Find the outliers using z-score normalization

# %%
#solution to q-4
for index, row in zsdf.iterrows():
    for val in row[:4]:
        if(abs(val)>3):
            print(row)
            continue
# Out:
# sepal length      -0.814237
# sepal width        0.213051
# petal length         3.3842
# petal width        -1.29815
# Class           Iris-setosa
# Name: 7, dtype: object
# sepal length        8.14481
# sepal width      -0.0316248
# petal length       -1.22817
# petal width        -1.29815
# Class           Iris-setosa
# Name: 30, dtype: object
# sepal length          -0.276694
# sepal width              11.305
# petal length          -0.129989
# petal width            0.133685
# Class           Iris-versicolor
# Name: 64, dtype: object

# %% [markdown]
# <b> Q-5: Normalize the dataset using min-max normalization

# %%
#solution to q-5
mmdf = df.copy()
for feature_name in mmdf.columns[:4]:
    max_value = mmdf[feature_name].max()
    min_value = mmdf[feature_name].min()
    mmdf[feature_name] = (mmdf[feature_name] - min_value) / (max_value - min_value)
mmdf
# Out:
#      sepal length  sepal width  petal length  petal width           Class
# 0        0.074766     0.100000      0.044444     0.041667     Iris-setosa
# 1        0.056075     0.066667      0.044444     0.041667     Iris-setosa
# 2        0.037383     0.080000      0.033333     0.041667     Iris-setosa
# 3        0.028037     0.073333      0.055556     0.041667     Iris-setosa
# 4        0.065421     0.106667      0.044444     0.041667     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145      0.224299     0.066667      0.466667     0.916667  Iris-virginica
# 146      0.186916     0.033333      0.444444     0.750000  Iris-virginica
# 147      0.205607     0.066667      0.466667     0.791667  Iris-virginica
# 148      0.177570     0.093333      0.488889     0.916667  Iris-virginica
# 149      0.149533          NaN      0.455556     0.708333  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# <b>Q-6:Write the code to discritize an attribute into 6 bins (third attribute)

# %%
#solution to q-6
disdf = df.copy()
disdf["petal length"]=pd.cut(disdf["petal length"], bins=6)
print(disdf.to_string())
# Out:
#      sepal length  sepal width  petal length  petal width            Class
# 0             5.1          3.5  (0.991, 2.5]          0.2      Iris-setosa
# 1             4.9          3.0  (0.991, 2.5]          0.2      Iris-setosa
# 2             4.7          3.2  (0.991, 2.5]          0.2      Iris-setosa
# 3             4.6          3.1  (0.991, 2.5]          0.2      Iris-setosa
# 4             5.0          3.6  (0.991, 2.5]          0.2      Iris-setosa
# 5             5.4          3.9  (0.991, 2.5]          0.4      Iris-setosa
# 6             4.6          3.4  (0.991, 2.5]          0.3      Iris-setosa
# 7             5.0          3.4   (8.5, 10.0]          0.2      Iris-setosa
# 8             4.4          2.9  (0.991, 2.5]          0.2      Iris-setosa
# 9             4.9          3.1  (0.991, 2.5]          0.1      Iris-setosa
# 10            5.4          3.7  (0.991, 2.5]          0.2      Iris-setosa
# ...

# %% [markdown]
# <b> Q-7:Find the correlation coeffiecient

# %%
#solution to q-7

# %%
df["sepal length"].corr(df["sepal width"])
# Out:
# -0.04572324835780275
